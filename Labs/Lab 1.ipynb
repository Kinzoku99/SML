# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Programu Operacyjnego Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# # Statistical machine learning - Notebook 1, version for students
# **Author: Michał Ciach**

# %% [markdown]
# ## Description

# %% [markdown]
# In today's class, we will learn the basic techniques of exploratory data analysis using the Python 3 programming language and the Jupyter Notebook.
# We will focus on the basic summary statistics such as the mean and the median, and the commonly used plot types such as the histogram and the boxplot.

# %% [markdown]
# In this and the next few classes, we will analyze the incomes of Polish municipalities (pl. *gminy*) in recent years.
# The data has been downloaded from the BDL database `https://bdl.stat.gov.pl/BDL/start` and is available in the Google drive of this course.

# %% [markdown]
# Run the cell below to download the data into the notebook's filesystem:

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1GW1pjKOCoKOlC4Jqbqql_ghYD_n0iC6O
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1GW1pjKOCoKOlC4Jqbqql_ghYD_n0iC6O
# To: /content/BDL municipality incomes 2015-2020.csv
# 100% 228k/228k [00:00<00:00, 67.0MB/s]

# %% [markdown]
# After running the cell above, you should have a file called `BDL municipality incomes 2015-2020.csv` in the list of the notebook's files (available in the left panel)

# %% [markdown]
# ## Importing Python libraries & loading the data

# %% [markdown]
# In this course, we will use the Pandas library for handling data and the Plotly library (mostly the Plotly Express module) for plotting.
# First, we import the required libraries and assign them more convenient names:

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# From now on, in example pieces of code, we will refer to Pandas as `pd` etc.
# Now, we will load the data from the `BDL municipality incomes 2015-2020.csv` file, using the `pd.read_csv()` function.
# In order to show the documentation of this function and learn how to use it, prepend the function name with a question sign:

# %%
## Run this cell to display the documentation of the pd.read_csv function.
# ?pd.read_csv

# %% [markdown]
# You may also google the name of the function to find more information about it.

# %% [markdown]
# **Exercise 0.** Read the data from the file `BDL municipality incomes 2015-2020.csv` into a data frame called `income`.

# %%
## Write your code here
income = pd.read_csv('./BDL municipality incomes 2015-2020.csv', sep=';',dtype={'Code': 'string'})

# %% [markdown]
# A good habit after reading the data into a Pandas data frame is to inspect the first few rows (the *head* of the data frame) and compare it to the original file to make sure that the input file is parsed correctly.

# %% [markdown]
# **Exercise 1.** Display the first rows of the `income` data frame by calling the method `income.head()`.
# Check if the data is read correctly by comparing it to the original file. If needed, adjust the parameters of the `pd.read_csv()` function.
# The most commonly adjusted parameters are `sep`, `header` and `dtype`.
# Display the last rows by calling `income.tail()` and check if you can already spot some features of the data set - e.g. whether it is sored with respect to some column.

# %%
## Write your code to display the head of the data frame here
income.head()
# Out:
#       Code            Region         2015         2016          2017  \
# 0  0201011   Bolesławiec (1)  97766455.51  96585948.26  1.003549e+08
# 1  0201022   Bolesławiec (2)  31072239.80  29138151.04  3.683091e+07
# 2  0201032      Gromadka (2)  10899408.78  13139743.96  1.454154e+07
# 3  0201043  Nowogrodziec (3)  18569147.18  29417467.57  3.188345e+07
# 4  0201052    Osiecznica (2)  16746467.73  17098022.83  1.760182e+07
#
#            2018          2019          2020
# 0  1.000265e+08  1.107985e+08  1.138563e+08
# 1  3.484836e+07  3.871533e+07  4.288890e+07
# 2  2.705794e+07  2.572157e+07  2.754443e+07
# 3  3.178886e+07  3.913420e+07  3.341908e+07
# 4  1.984173e+07  2.177626e+07  2.484304e+07

# %%
## Write your code to display the tail of the data frame here
income.tail()
# Out:
#          Code           Region          2015          2016          2017  \
# 2504  3218043        Resko (3)  1.523513e+07  1.448583e+07  1.611091e+07
# 2505  3218053    Węgorzyno (3)  1.069708e+07  1.037428e+07  1.082646e+07
# 2506  3261011     Koszalin (1)  2.697281e+08  2.891235e+08  3.054048e+08
# 2507  3262011     Szczecin (1)  1.350327e+09  1.372046e+09  1.343422e+09
# 2508  3263011  Świnoujście (1)  1.485720e+08  2.257467e+08  2.170850e+08
#
#               2018          2019          2020
# 2504  1.763241e+07  1.760038e+07  1.941628e+07
# 2505  1.201310e+07  1.359405e+07  2.503944e+07
# 2506  3.245613e+08  3.432316e+08  3.840694e+08
# 2507  1.431826e+09  1.545381e+09  1.739014e+09
# 2508  2.617808e+08  1.676388e+08  2.630070e+08

# %% [markdown]
# ## Data handling

# %% [markdown]
# Now, we will learn the basic operations on data frames: removing and adding new columns.

# %% [markdown]
# **Exercise 2.** Use the function `pd.DataFrame.drop()` to remove the columns with income from the 2015-2018 from the `income` data frame.
# **Hint:** The function `pd.DataFrame.drop()` refers to a method of a Pandas DataFrame object. To actually use it on a DataFrame such as `income`, you simply write `income.drop()`. There are two ways of displaying the documentation of this function: either `?pd.DataFrame.drop` or `income.drop`.

# %%
## Write your code to drop the columns here. Use income.head() to check if it worked correctly.
income.drop(labels=['2015', '2016', '2017', '2018'], axis=1, inplace=True)
income.head()
# Out:
#       Code            Region          2019          2020
# 0  0201011   Bolesławiec (1)  1.107985e+08  1.138563e+08
# 1  0201022   Bolesławiec (2)  3.871533e+07  4.288890e+07
# 2  0201032      Gromadka (2)  2.572157e+07  2.754443e+07
# 3  0201043  Nowogrodziec (3)  3.913420e+07  3.341908e+07
# 4  0201052    Osiecznica (2)  2.177626e+07  2.484304e+07

# %% [markdown]
# To add some variable `x` as a column named `column_name` to our data frame `income`, we write `income["column_name"] = x`.
# We will use this to add a column with territorial codes of voivodeships to the `income` data frame.
# The voivodeship is designated by the first two digits of a territorial code of a municipality.
# The Python dictionary below maps the voivodeship codes to their names.

# %%
voivodeship_names = {
    '02': 'Dolnośląskie',
    '04': 'Kujawsko-pomorskie',
    '06': 'Lubelskie',
    '08': 'Lubuskie',
    '10': 'Łódzkie',
    '12': 'Małopolskie',
    '14': 'Mazowieckie',
    '16': 'Opolskie',
    '18': 'Podkarpackie',
    '20': 'Podlaskie',
    '22': 'Pomorskie',
    '24': 'Śląskie',
    '26': 'Świętokrzyskie',
    '28': 'Warmińsko-mazurskie',
    '30': 'Wielkopolskie',
    '32': 'Zachodniopomorskie'
}

# %% [markdown]
# **Exercise 3.** Add a column called `Voivodeship` that contains the name of the voivodeship of each region to the `income` data frame.
# **Hint:** You can use the Python list comprehension to generate a list containing the fist two digits of each territorial code.
# Next, use the `voivodeship_names` dictionary to convert the voivodeship codes to their names.

# %%
## Write your code here. Use income.head() to check your results.
code_list = [s[:2] for s in income['Code']]
name_list = [voivodeship_names[code] for code in code_list]
income['Voivodeship'] = name_list
income.head()
# Out:
#       Code            Region          2019          2020   Voivodeship
# 0  0201011   Bolesławiec (1)  1.107985e+08  1.138563e+08  Dolnośląskie
# 1  0201022   Bolesławiec (2)  3.871533e+07  4.288890e+07  Dolnośląskie
# 2  0201032      Gromadka (2)  2.572157e+07  2.754443e+07  Dolnośląskie
# 3  0201043  Nowogrodziec (3)  3.913420e+07  3.341908e+07  Dolnośląskie
# 4  0201052    Osiecznica (2)  2.177626e+07  2.484304e+07  Dolnośląskie

# %% [markdown]
# ## Basic summary statistics

# %% [markdown]
# As a first statistical exercice, we will inspect the basic summary statistics of the income.
# To do this, we use the function `income.describe()`. This function will print the number of observations, their mean, standard deviation and quartiles for each numerical column of the `income` data frame. To describe a single column, we may also write `income["2020"].describe()`.

# %% [markdown]
# **Exercise 4.** Use the `income.describe()` function to inspect the values of the debt. What are the minimum, the median, and the maximum values? Can you notice something suspicious about those values?

# %%
## Write your code here
income.describe()
# Out:
#                2019          2020
# count  2.477000e+03  2.477000e+03
# mean   4.583969e+07  4.912910e+07
# std    3.069213e+08  3.008586e+08
# min    0.000000e+00  2.309878e+06
# 25%    7.832875e+06  9.574931e+06
# 50%    1.390252e+07  1.627315e+07
# 75%    2.921135e+07  3.335708e+07
# max    1.303188e+10  1.260886e+10

# %% [markdown]
# ## Basic data visualization

# %% [markdown]
# In the last section of this tutorial, we will learn how to create two types of plots that are commonly used to describe the distributions of numerical observations: the *histogram* and the *box plot* (pl. wykres pudełkowy).

# %% [markdown]
# ### Histograms
# A histogram is a graph that shows the counts of observations that fall within given bins.
# It is used to inspect the *shape* of the distribution - whether it is symmetric, unimodal etc.
# It can also be used to inspect the range of the observations (the minimum and maximum values), but is not very useful to inspect other summary statistics, such as quartiles.

# %% [markdown]
# This is how we construct a default histogram of a given column of a Pandas data frame using the Plotly Express plotting library.

# %%
px.histogram(income, x='2020', title="Income of Polish municipalities in 2020", labels={'2020': 'Income in PLN'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0a81089e-ac7d-4386-a59a-c869667bc4f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a81089e-ac7d-4386-a59a-c869667bc4f3")) {                    Plotly.newPlot(                        "0a81089e-ac7d-4386-a59a-c869667bc4f3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Income in PLN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[113856301.52,42888896.64,27544426.64,33419083.79,24843042.47,19244802.71,67916257.23,79686672.41,null,16575176.13,15968081.14,19776268.15,20711591.63,15136792.17,234749248.45,22477371.22,44915504.21,15282435.95,4519383.48,16801390.12,43795233.75,5792514.73,9881556.67,14920264.11,64163194.85,26250564.54,20146295.66,11497947.97,11700645.36,10749305.96,28318587.3,22755724.99,19512569.74,32337749.37,10369907.99,20735950.99,25210593.75,24969
class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8b9cc60-9bd8-497a-9224-f60099e65575")) {                    Plotly.newPlot(                        "c8b9cc60-9bd8-497a-9224-f60099e65575",                        [{"alignmentgroup":"True","hovertemplate":"Voivodeship=%{x}\u003cbr\u003eIncome in PLN=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Dolno\u015bl\u0105skie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomorskie","Kujawsko-pomor ...

# %% [markdown]
# ### Scatter plots
# Scatter plots are used to represent two-dimentional distributions, or pairs of values.
# They simply represent pairs of values as points, and are mostly useful to check the two-dimentional shape of the distribution, the correlation between variables, their ranges etc., but do not tell us almost anything about the summary statistics.

# %% [markdown]
# This is how we create a basic scatter plot in Plotly Express.
# We will add a straight line using the `add_scatter` method to visualize how the income has changed from 2019 to 2020.
# Note that we don't need to specify the data frame in `px.add_scatter`, we just pass numerical data to the `x` and `y` variables.

# %%
fig = px.scatter(income, x='2019', y='2020', title='Income of Polish municipalities in 2020 vs 2019')
fig.add_scatter(x=[0, 13.5e09], y=[0, 13.5e09], showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bd5f303b-1f58-4636-ad92-d9ca990173fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd5f303b-1f58-4636-ad92-d9ca990173fd")) {                    Plotly.newPlot(                        "bd5f303b-1f58-4636-ad92-d9ca990173fd",                        [{"hovertemplate":"2019=%{x}\u003cbr\u003e2020=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[110798547.62,38715326.98,25721571.91,39134198.61,21776258.65,18054695.18,70138044.84,81664887.31,null,16636494.2,11221924.55,16220712.22,12636384.32,11044673.97,220202473.52,22045446.05,37591134.35,9329098.78,3641754.1,10389313.13,41203198.29,5386402.14,7653772.98,12834082.03,49149261.26,15473406.99,14372334.92,8212910.54,9269665.78,9763756.79,30802431.79,20847650.57,17391057.15,33246468.17,9124914.34,18279527.03,23009737.79,20852342.76,11531567.12,40787953.85,17744171.41,15327600.28,7042261.6,15110278.81,59640612.47,26159089.36,47106251.52,21834561.93,38091852.27,32094889.19,38645734.73,4943836.82,9996516.0,20893017.56,23709252.81,15610242.43,11536137.14,29895012.62,22261602.31,9382763.88,22371294.3,23651030.62,15758222.13,19521116.35,4922210.72,48419292.45,22347289.27,14759762.84,11933182.28,11094075.76,3594296.22,9507468.45,230681502.12,78292175.92,45380493.52,21123353.83,16718960.99,7433331.7,32388510.86,12299367.82,6455727.9,7737031.2,23423245.62,48281370.19,135857036.58,15720323.41,14969955.16,7360562.94,9140508.2,32544192.36,33786353.94,36549816.91,86917851.45,10222225.47,71141381.18,51533417.09,26457012.5,6765334.44,37488562.74,212164954.3,14252777.34,20569792.79,8818387.95,8440342.37,6165381.92,60719925.99,14076073.87,14685016.57,12930281.83,55077967.86,58306866.81,9890529.67,163023023.45,59673833.27,11168580.87,21197519.25,12695656.44,74002034.02,40027701.64,34826916.44,51610787.64,16984499.2,58882742.14,31207899.02,18435596.75,29944294.5,0.0,10367513.68,27353092.57,13012175.83,13660933.89,16459521.05,6634120.59,13248204.37,54023587.39,19785598.18,46900251.64,47848683.7,119458203.39,7202244.19,96007072.62,183871214.47,9698160.83,35922668.11,91548709.63,34683425.09,12340556.45,6707039.31,16944105.72,7894620.87,51439165.49,30101077.18,6999491.68,8490116.54,70694342.83,125135270.66,17639692.64,15250093.44,16353804.26,26110774.59,7808351.17,38873219.81,7628527.1,12133224.87,11010332.28,16981943.77,233982559.26,324578319.36,3353248953.04,345485520.23,22758548.96,32246564.72,3861400.25,17542693.8,7281048.96,6542325.16,4869937.05,7942064.89,7458161.62,69803255.55,9689057.69,18707206.2,5502726.85,6701494.07,8294133.87,13594878.23,6178015.16,5696071.25,7365777.62,72152266.19,17640553.5,23507380.67,55343147.72,28306548.57,73572220.08,27429526.3,53603705.66,36493201.0,6979893.68,7637047.91,9951506.17,6027596.49,11581375.1,10540636.49,25156516.32,7110563.64,15453571.71,21292903.55,6165221.7,6242604.88,37330152.08,10826919.36,17120435.93,14371027.08,5740472.32,7307720.87,231429285.08,9898289.18,24790749.72,30517236.48,34441148.35,43236888.25,20113883.69,8780441.92,14478351.0,23965528.95,5124426.95,4715142.76,13785881.98,9938731.94,18432445.35,13009057.22,7952532.25,9337070.17,8592099.62,9019063.61,59393165.63,22122912.85,19589232.14,15253956.95,64886470.16,12277441.1,51849705.37,13096009.88,5000741.33,9150355.8,9280598.72,13645939.15,9193701.24,6656892.57,40006365.71,5941785.89,5766384.48,13223140.95,7267696.75,5053113.58,11178653.21,34535001.33,8450062.68,19598638.7,11391902.83,14068495.21,8095145.01,11516408.78,6420441.94,15427352.68,12882130.84,15268636.14,120103753.4,6867592.13,13541402.05,30105732.86,16757104.42,10792432.73,49093705.47,19799268.91,31838763.17,33002607. ...

# %% [markdown]
# **Exercise 7.** Create a scatter plot showing the income in years 2019 and 2020 for those municipalities that had an income lower than **50** mln PLN in the year **2019**. Add a straight line and check visually if the incomes have increased or decreased.
# Can you see something suspicious in the plot?

# %% [markdown]
# **Exercise 8 - homework:** Search Google for examples of using the `hover_data` and `hover_name` arguments in Plotly plots.
# Use the `hover_data` argument of `px.scatter` to add the voivodeship name to the information about the data points and the `hover_name` argument to add the region name. Use this to identify regions with suspicious data.

# %%
fig = px.scatter(income[income['2019'] < 5e7], x='2019', y='2020', hover_name='Region', hover_data=income[['2019', '2020', 'Voivodeship']])
fig.add_scatter(x=[0, 5e7], y=[0, 5e7], showlegend=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="daf7eb03-22f9-4148-9071-76c9bb5f7c27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daf7eb03-22f9-4148-9071-76c9bb5f7c27")) {                    Plotly.newPlot(                        "daf7eb03-22f9-4148-9071-76c9bb5f7c27",                        [{"customdata":[["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u0105skie"],["Dolno\u015bl\u010 ...

# %% [markdown]
# ## Summary

# %% [markdown]
# **Things to memorize:**
# - Use Pandas to handle data. Inspect the fist few rows after loading data. Specify the column formats when needed.
# - Use Plotly to create plots. One of the ways of creating more detailed plots is to use vectorized operations to select rows of data frames.
# - Histograms show the shape of a distribution, but are not useful to check quantitative statistics such as the median.
# - Boxplots show quantitative statistics, but are not useful to check the shape of the distribution.
# - Scatter plots show two-dimentional distributions.

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>
